# %%
temp = [34.38, 34.36, 35.26, 35.23, 35.29, 35.64,
        36.02, 36.10, 36.98, 37.01, 36.75, 37.01,
        35.66, 34.72, 33.90, 32.62, 31.51, 30.73,
        29.50, 26.94, 30.31, 31.30, 32.33, 33.01]
n = 24

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.array(range(len(temp))).reshape(-1,1)

# %%
plt.plot(X,temp)

# %%
from sklearn.svm import SVR
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.linear_model import LinearRegression

# %%
#model = SVR(kernel="linear")
#model = GaussianProcessRegressor()
#model = LinearRegression()
#model.fit(X, temp)

# %%
# HWES example
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# fit model
model = ExponentialSmoothing(temp, seasonal="add",seasonal_periods=24)

model0_fit = model.fit()
# make prediction
#for i in range(n):
yfit = model_fit.predict(start=1, end=24)
# Out:
# /home/robin/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/holtwinters.py:734: RuntimeWarning: divide by zero encountered in log
#   aic = self.nobs * np.log(sse / self.nobs) + (k) * 2
# /home/robin/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/holtwinters.py:736: RuntimeWarning: divide by zero encountered in log
#   bic = self.nobs * np.log(sse / self.nobs) + (k) * np.log(self.nobs)

# %%
plt.plot(X,temp,'*')
#plt.plot(X, model.predict(X))
plt.plot(X,yfit)

# %%
X_test = np.array(range(len(temp)+1,len(temp)+n+1)).reshape(-1,1)

# %%
#yhat = model.predict(X_test)
seentemp = [x for x in temp]
pred = []
for i in range(n):
    model_unfit = ExponentialSmoothing(temp, seasonal="add", seasonal_periods=24)
    model_fit = model_unfit.fit()
    yhat = model_fit.predict(len(seentemp),len(seentemp))
    pred.append(yhat)
    seentemp.append(yhat)
# Out:
# /home/robin/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/holtwinters.py:734: RuntimeWarning: divide by zero encountered in log
#   aic = self.nobs * np.log(sse / self.nobs) + (k) * 2
# /home/robin/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/holtwinters.py:736: RuntimeWarning: divide by zero encountered in log
#   bic = self.nobs * np.log(sse / self.nobs) + (k) * np.log(self.nobs)

# %%
pred0 = model0_fit.predict(1,48)
# Out:
# /home/robin/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/holtwinters.py:734: RuntimeWarning: divide by zero encountered in log
#   aic = self.nobs * np.log(sse / self.nobs) + (k) * 2
# /home/robin/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/holtwinters.py:736: RuntimeWarning: divide by zero encountered in log
#   bic = self.nobs * np.log(sse / self.nobs) + (k) * np.log(self.nobs)

# %%
plt.plot(X,temp,'*')
#plt.plot(X, model.predict(X))
plt.plot(range(24,48), pred, 'r')
plt.plot(range(48),pred0,'y')
